# %%
#Q4: Calculate the sum of digits of a three-digit Number
name = "jawad ul hassan"
age = 23
height=5.6

print("My name is %s and i am %d years old and my height is %f." % (name, age, height))
# Out:
# My name is jawad ul hassan and i am 23 years old and my height is 5.600000.
