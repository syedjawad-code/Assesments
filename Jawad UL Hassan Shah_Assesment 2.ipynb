# %%
#Task 1: Printing a Message

print('Hello, everyone! i am learning python')
# Out:
# Hello, everyone! i am learning python

# %%
#Task 2: Declaring Variables
name= 'jawad'
age= 20
favorite_animal= 'cat'

print('My name is', name)
print('My age is',age)
print('My favorite animal is' , favorite_animal)
# Out:
# My name is jawad
# My age is 20
# My favorite animal is cat

# %%
#Task 3: Combining Variables in a Message
print(f'My name is {name},My age is {age},My favorite animal is {favorite_animal}')
# Out:
# My name is jawad,My age is 20,My favorite animal is cat

# %%
#Task 4: Playing with Different Data Types
favorite_movie = "Toy Story"
birth_year = 2010
price_of_snack = 1.5

print("Favorite Movie:", favorite_movie)
print("Birth Year:", birth_year)
print("Price of Snack:", price_of_snack)
# Out:
# Favorite Movie: Toy Story
# Birth Year: 2010
# Price of Snack: 1.5

# %%
#Task 5: Your Favorite Hobby

hobby = "reading books"

print("My favorite hobby is", hobby)
# Out:
# My favorite hobby is reading books

# %%
#Extra Challenge
a=5
b=7
c=a+b
print(c)
# Out:
# 12
